# %%
import kagglehub

# Load and preprocess the dataset
path = kagglehub.dataset_download("abhinavmoudgil95/short-jokes")

# Print the path where the dataset is saved
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/short-jokes

# %%
import pandas as pd

# Load and preprocess the dataset
jokes_data = pd.read_csv(path + "/shortjokes.csv")

# Display the first few rows of the dataset
print(jokes_data.head())
# Out:
#    ID                                               Joke
# 0   1  [me narrating a documentary about narrators] "...
# 1   2  Telling my daughter garlic is good for you. Go...
# 2   3  I've been going through a really rough period ...
# 3   4  If I could have dinner with anyone, dead or al...
# 4   5     Two guys walk into a bar. The third guy ducks.

# %%
# Check the structure of the dataset
print(jokes_data.info())

# Display the first few rows
print(jokes_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231657 entries, 0 to 231656
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      231657 non-null  int64
#  1   Joke    231657 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 3.5+ MB
# None
#    ID                                               Joke
# 0   1  [me narrating a documentary about narrators] "...
# 1   2  Telling my daughter garlic is good for you. Go...
# 2   3  I've been going through a really rough period ...
# 3   4  If I could have dinner with anyone, dead or al...
# 4   5     Two guys walk into a bar. The third guy ducks.

# %%
jokes_data = jokes_data.sample(n=5000, random_state=42)

# %%
jokes_data.loc[4510]
# Out:
# ID                                                   4511
# Joke    What do all battered women have in common? The...
# Name: 4510, dtype: object

# %%
jokes_data['Joke'] = jokes_data['Joke'].str.strip()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Tokenize and create sequences

tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(jokes_data['Joke'])

# %%
len(token.word_index)
# Out:
# 10485

# %%
input_sequences=[]
for sentence in jokes_data['Joke']:
    tokenized_sentence = token.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        input_sequences.append(tokenized_sentence[:i+1])

# %%
max_len = max([len(x) for x in input_sequences])
max_len
# Out:
# 44

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
# Prepare data for training

X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (83483, 43)

# %%
y.shape
# Out:
# (83483,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=10486)

# %%
y.shape
# Out:
# (83483, 10486)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
# Build and train the model

model = Sequential()
model.add(Embedding(10486, 100, input_length=43))
model.add(LSTM(150))
model.add(Dense(10486, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_12 (LSTM)                       │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X, y,
    epochs=100,
    batch_size=64,
    #validation_split=0.2,  # Automatically split 20% of data for validation
    #callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.0411 - loss: 7.3326
# Epoch 2/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.0788 - loss: 6.4679
# Epoch 3/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.1158 - loss: 5.9483
# Epoch 4/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.1410 - loss: 5.5362
# Epoch 5/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.1648 - loss: 5.1509
# Epoch 6/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.1835 - loss: 4.8109
# Epoch 7/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.2060 - loss: 4.4826
# Epoch 8/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.2355 - loss: 4.1551
# Epoch 9/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.2693 - loss: 3.8626
# Epoch 10/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.3138 - loss: 3.5614
# Epoch 11/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.3539 - loss: 3.3086
# Epoch 12/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.3907 - loss: 3.0917
# Epoch 13/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.4246 - loss: 2.8793
# Epoch 14/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.4576 - loss: 2.6905
# Epoch 15/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.4845 - loss: 2.5282
# Epoch 16/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5131 - loss: 2.3699
# Epoch 17/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5446 - loss: 2.2140
# Epoch 18/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5640 - loss: 2.0990
# Epoch 19/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.5906 - loss: 1.9649
# Epoch 20/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.6144 - loss: 1.8593
# Epoch 21/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.6322 - loss: 1.7623
# Epoch 22/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6542 - loss: 1.6526
# Epoch 23/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.6714 - loss: 1.5730
# Epoch 24/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6903 - loss: 1.4863
# Epoch 25/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7091 - loss: 1.3980
# Epoch 26/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7227 - loss: 1.3265
# Epoch 27/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7351 - loss: 1.2623
# Epoch 28/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7449 - loss: 1.2104
# Epoch 29/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7615 - loss: 1.1459
# Epoch 30/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7679 - loss: 1.0945
# Epoch 31/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.7841 - loss: 1.0323
# Epoch 32/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.7929 - loss: 0.9903
# Epoch 33/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8001 - loss: 0.9552
# Epoch 34/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.8121 - loss: 0.9075
# Epoch 35/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8185 - loss: 0.8754
# Epoch 36/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8275 - loss: 0.8328
# Epoch 37/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8332 - loss: 0.7976
# Epoch 38/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8382 - loss: 0.7784
# Epoch 39/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8469 - loss: 0.7431
# Epoch 40/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8520 - loss: 0.7107
# Epoch 41/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8582 - loss: 0.6842
# Epoch 42/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8625 - loss: 0.6616
# Epoch 43/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8672 - loss: 0.6403
# Epoch 44/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8709 - loss: 0.6156
# Epoch 45/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.8779 - loss: 0.5850
# Epoch 46/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8788 - loss: 0.5816
# Epoch 47/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8844 - loss: 0.5530
# Epoch 48/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8851 - loss: 0.5473
# Epoch 49/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8878 - loss: 0.5311
# Epoch 50/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8925 - loss: 0.5154
# Epoch 51/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.8928 - loss: 0.5046
# Epoch 52/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8957 - loss: 0.4898
# Epoch 53/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.8970 - loss: 0.4831
# Epoch 54/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.8969 - loss: 0.4771
# Epoch 55/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9028 - loss: 0.4561
# Epoch 56/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9008 - loss: 0.4557
# Epoch 57/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9071 - loss: 0.4327
# Epoch 58/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9064 - loss: 0.4329
# Epoch 59/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9069 - loss: 0.4244
# Epoch 60/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9075 - loss: 0.4195
# Epoch 61/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9079 - loss: 0.4130
# Epoch 62/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9080 - loss: 0.4093
# Epoch 63/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9093 - loss: 0.3999
# Epoch 64/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9093 - loss: 0.3994
# Epoch 65/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9123 - loss: 0.3899
# Epoch 66/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9109 - loss: 0.3918
# Epoch 67/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9131 - loss: 0.3795
# Epoch 68/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9112 - loss: 0.3848
# Epoch 69/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9125 - loss: 0.3787
# Epoch 70/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9137 - loss: 0.3744
# Epoch 71/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9151 - loss: 0.3646
# Epoch 72/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9143 - loss: 0.3667
# Epoch 73/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9128 - loss: 0.3670
# Epoch 74/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9140 - loss: 0.3636
# Epoch 75/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9150 - loss: 0.3561
# Epoch 76/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9164 - loss: 0.3478
# Epoch 77/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9150 - loss: 0.3557
# Epoch 78/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9148 - loss: 0.3569
# Epoch 79/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9159 - loss: 0.3478
# Epoch 80/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9141 - loss: 0.3519
# Epoch 81/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9169 - loss: 0.3414
# Epoch 82/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9152 - loss: 0.3463
# Epoch 83/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9170 - loss: 0.3407
# Epoch 84/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9152 - loss: 0.3448
# Epoch 85/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9172 - loss: 0.3375
# Epoch 86/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9157 - loss: 0.3394
# Epoch 87/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9148 - loss: 0.3445
# Epoch 88/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9175 - loss: 0.3352
# Epoch 89/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9186 - loss: 0.3311
# Epoch 90/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9148 - loss: 0.3400
# Epoch 91/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9163 - loss: 0.3404
# Epoch 92/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9177 - loss: 0.3308
# Epoch 93/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9180 - loss: 0.3285
# Epoch 94/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9188 - loss: 0.3254
# Epoch 95/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9165 - loss: 0.3311
# Epoch 96/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9163 - loss: 0.3320
# Epoch 97/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9192 - loss: 0.3175
# Epoch 98/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9179 - loss: 0.3242
# Epoch 99/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.9147 - loss: 0.3359
# Epoch 100/100
# 1305/1305 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.9176 - loss: 0.3242

# %%
# Text prediction example

import numpy as np
import time
text = "women"

for i in range(30):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=44, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# women are
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# women are like stars at
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# women are like stars at first they are
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# women are like stars at first they are small and hot then they get
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# women are like stars at first they are small and hot then they get bigger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything around
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything around them
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything around them they
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything around them they are
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# women are like stars at first they are small and hot then they get bigger and bigger then finally they suck the life out of everything around them they are already
